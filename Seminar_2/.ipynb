# %% [markdown]
# # Second seminar

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

mpl.rcParams["axes.grid"] = False
def graphics(x = 16, y = 12):
    mpl.rcParams["figure.figsize"] = (x, y)
graphics(12, 8)

# %%
phi = np.linspace(-np.pi / 2, np.pi / 2, 100)
r = np.sin(-phi / 2)
plt.polar(phi, r, color=(1,0,0.2))
plt.polar(3 * np.pi - phi, r, color=(1,0,0.2) )
# plt.show()

# %%
phi = np.linspace(0, np.pi *2, 100)
r = np.sin(phi * 5)
plt.polar(phi, r, color=(1,0,0.2))
# plt.show()

# %% [markdown]
# $$
#     L[u] = f
# $$
# $$
#     Ly < 0,\ y_b < 0,\ y < 0
# $$
